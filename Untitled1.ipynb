# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15598, done.
# remote: Counting objects: 100% (205/205), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 15598 (delta 97), reused 119 (delta 56), pack-reused 15393
# Receiving objects: 100% (15598/15598), 14.58 MiB | 30.84 MiB/s, done.
# Resolving deltas: 100% (10626/10626), done.

# %%
# %cd yolov5
# !pip install -qr requirements.txt
import torch
from IPython.display import Image,clear_output
print('complete')
# Out:
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.3 MB/s eta 0:00:00
# complete

# %%
# !unzip /content/ezyzip.zip
# Out:
# Archive:  /content/ezyzip.zip
#   inflating: data.yaml
#    creating: train/
#    creating: train/labels/
#   inflating: train/labels/820SMN_Face_Mask_Mens_Adult_Navy.txt
#   inflating: train/labels/classes.txt
#   inflating: train/labels/download (1).txt
#   inflating: train/labels/download (12).txt
#   inflating: train/labels/download (13).txt
#   inflating: train/labels/download (14).txt
#   inflating: train/labels/download (15).txt
#   inflating: train/labels/download (16).txt
#   inflating: train/labels/download (17).txt
#   inflating: train/labels/download (18).txt
#   inflating: train/labels/download (19).txt
#   inflating: train/labels/download (2).txt
#   inflating: train/labels/download (3).txt
#   inflating: train/labels/download (4).txt
#   inflating: train/labels/download (5).txt
#   inflating: train/labels/download (6).txt
#   inflating: train/labels/download (7).txt
#   inflating: train/labels/images (10).txt
#   inflating: train/labels/images (11).txt
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 300 --data /content/yolov5/data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-155-g8ecc727 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
from utils.plots import plot_results
Image(filename='/content/yolov5/runs/train/exp/results.png',width=1000)

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/yolov5/test/images
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/yolov5/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-155-g8ecc727 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/11 /content/yolov5/test/images/download (10).jpg: 416x288 1 mask, 38.5ms
# image 2/11 /content/yolov5/test/images/download (11).jpg: 416x288 1 mask, 5.8ms
# image 3/11 /content/yolov5/test/images/download (8).jpg: 320x416 1 mask, 40.5ms
# ...
